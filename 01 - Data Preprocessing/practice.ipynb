# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("data.csv")

X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
print(X)
print(y)
# Out:
# [['France' 44.0 72000.0]
#  ['Spain' 27.0 48000.0]
#  ['Germany' 30.0 54000.0]
#  ['Spain' 38.0 61000.0]
#  ['Germany' 40.0 nan]
#  ['France' 35.0 58000.0]
#  ['Spain' nan 52000.0]
#  ['France' 48.0 79000.0]
#  ['Germany' 50.0 83000.0]]
# ['No' 'Yes' 'No' 'No' 'Yes' 'Yes' 'No' 'Yes' 'No']

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
imputer.fit(X[:, 1:3])
X[:, 1:3] = imputer.transform(X[:, 1:3])

# %%
print(X)
# Out:
# [['France' 44.0 72000.0]
#  ['Spain' 27.0 48000.0]
#  ['Germany' 30.0 54000.0]
#  ['Spain' 38.0 61000.0]
#  ['Germany' 40.0 63375.0]
#  ['France' 35.0 58000.0]
#  ['Spain' 39.0 52000.0]
#  ['France' 48.0 79000.0]
#  ['Germany' 50.0 83000.0]]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [0])], remainder='passthrough')
X = np.array(ct.fit_transform(X))

# %%
print(X)
# Out:
# [[1.0 0.0 0.0 44.0 72000.0]
#  [0.0 0.0 1.0 27.0 48000.0]
#  [0.0 1.0 0.0 30.0 54000.0]
#  [0.0 0.0 1.0 38.0 61000.0]
#  [0.0 1.0 0.0 40.0 63375.0]
#  [1.0 0.0 0.0 35.0 58000.0]
#  [0.0 0.0 1.0 39.0 52000.0]
#  [1.0 0.0 0.0 48.0 79000.0]
#  [0.0 1.0 0.0 50.0 83000.0]]

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y = le.fit_transform(y)

# %%
print(y)
# Out:
# [0 1 0 0 1 1 0 1 0]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=1)
print(X_train, X_test, y_train, y_test)
# Out:
# [[0.0 0.0 1.0 39.0 52000.0]
#  [1.0 0.0 0.0 48.0 79000.0]
#  [0.0 0.0 1.0 27.0 48000.0]
#  [1.0 0.0 0.0 44.0 72000.0]
#  [0.0 1.0 0.0 40.0 63375.0]
#  [0.0 0.0 1.0 38.0 61000.0]
#  [1.0 0.0 0.0 35.0 58000.0]] [[0.0 1.0 0.0 50.0 83000.0]
#  [0.0 1.0 0.0 30.0 54000.0]] [0 1 1 0 1 0 1] [0 0]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train[:, 3:] = scaler.fit_transform(X_train[:, 3:])
X_test[:, 3:] = scaler.transform(X_test[:, 3:])

# %%
print(f'{X_train}\n\n{X_test}')
# Out:
# [[0.0 0.0 1.0 0.046225016352102265 -0.988367830494171]
#  [1.0 0.0 0.0 1.5023130314433286 1.7042666915007605]
#  [0.0 0.0 1.0 -1.8952256704361996 -1.387276648567494]
#  [1.0 0.0 0.0 0.8551628025138948 1.006176259872445]
#  [0.0 1.0 0.0 0.20801257358446076 0.14602912090184184]
#  [0.0 0.0 1.0 -0.11556254088025623 -0.0908229898291938]
#  [1.0 0.0 0.0 -0.6009252125773317 -0.3900046033841862]]
#
# [[0.0 1.0 0.0 1.8258881459080456 2.1031755095740836]
#  [0.0 1.0 0.0 -1.4098629987391242 -0.7889134214575094]]
